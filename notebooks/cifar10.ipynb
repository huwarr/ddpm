# %%
#!g1.1
# !git clone https://github.com/huwarr/ddpm.git
# Out:
# Cloning into 'ddpm'...

# %%
#!g1.1
# %cd ddpm
# Out:
# /home/jupyter/work/resources/ddpm

# %%
#!g1.1
# %pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 15.8 MB 1.6 MB/s
# ...
#      |████████████████████████████████| 41.6 MB 38 kB/s
# ...
#      |████████████████████████████████| 776.3 MB 2.7 kB/s
# ...
#      |████████████████████████████████| 512 kB 61.8 MB/s
# ...
#      |████████████████████████████████| 19.1 MB 57.3 MB/s
# ...
#      |████████████████████████████████| 76 kB 5.4 MB/s
# ...
#   WARNING: The scripts convert-caffe2-to-onnx, convert-onnx-to-caffe2 and torchrun are installed in '/home/jupyter/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts f2py, f2py3 and f2py3.8 are installed in '/home/jupyter/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...

# %%
#!g1.1
import os

os.environ['PATH'] += ':/home/jupyter/.local/bin'

# %%
#!g1.1
from train import train_func
from sample import sample_func
from model.ddpm import UNet

import torch
import wandb
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt

# %% [markdown]
# ### Training

# %%
#!g1.1
torch.manual_seed(42)
model = UNet(in_channels=3, dropout=0.1, T=1000)

wandb.login(key='197611a3eaae3655a918f65b0f106bbce7ab7a74')
wandb.init(project='ddpm_cifar10')

losses, ema = train_func(model, 'CIFAR10', n_steps=800000, use_wandb=True, sample_during_training=True)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: huwarr. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /home/jupyter/.netrc
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/home/jupyter/work/resources/ddpm/wandb/run-20221204_185549-el2qzh0l</code>
# Syncing run <strong><a href="https://wandb.ai/huwarr/ddpm_cifar10/runs/el2qzh0l" target="_blank">sunny-capybara-2</a></strong> to <a href="https://wandb.ai/huwarr/ddpm_cifar10" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# ...

# %%
#!g1.1
plt.figure(figsize=(8, 5))
plt.plot(losses)
plt.title("Loss during training")
plt.xlabel('Training step')
plt.ylabel('MSE')
plt.show()
print('Loss: {}'.format(losses[-1]))
# Out:
# Loss: 0.02864934876561165

# %%
#!g1.1
model
# Out:
# UNet(
#   (in_block): Conv2d(3, 32, kernel_size=(1, 1), stride=(1, 1))
#   (out_block): Conv2d(32, 3, kernel_size=(1, 1), stride=(1, 1))
#   (down_blocks): ModuleList(
#     (0): DownBlock(
#       (block_1): ConvResidBlock(
#         (basic_block): Sequential(
#           (0): GroupNorm(32, 32, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (3): GroupNorm(32, 64, eps=1e-05, affine=True)
#           (4): SiLU()
#           (5): Dropout(p=0.1, inplace=False)
#           (6): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (conv1): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#         (t_encoding): TransformerSinusoidalEncoding()
#       )
#       (block_2): ConvResidBlock(
#         (basic_block): Sequential(
#           (0): GroupNorm(32, 64, eps=1e-05, affine=True)
#           (1): SiLU()
# ...

# %%
#!g1.1
ema
# Out:
# EMA(
#   (online_model): UNet(
#     (in_block): Conv2d(3, 32, kernel_size=(1, 1), stride=(1, 1))
#     (out_block): Conv2d(32, 3, kernel_size=(1, 1), stride=(1, 1))
#     (down_blocks): ModuleList(
#       (0): DownBlock(
#         (block_1): ConvResidBlock(
#           (basic_block): Sequential(
#             (0): GroupNorm(32, 32, eps=1e-05, affine=True)
#             (1): SiLU()
#             (2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (3): GroupNorm(32, 64, eps=1e-05, affine=True)
#             (4): SiLU()
#             (5): Dropout(p=0.1, inplace=False)
#             (6): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#           (conv1): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#           (t_encoding): TransformerSinusoidalEncoding()
#         )
#         (block_2): ConvResidBlock(
#           (basic_block): Sequential(
#             (0): GroupNorm(32, 64, eps=1e-05, affine=True)
# ...

# %%
#!g1.1
torch.save(model, 'model.pth')

# %%
#!g1.1
torch.save(ema, 'ema.pth')

# %% [markdown]
# ### Sampling

# %%
#!g1.1
samples, steps, _ = sample_func(ema, n_samples=10, use_wandb=False)
# Out:
# Sampling:   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
#!g1.1
samples = torch.clamp((samples + 1) * 127.5, 0, 255).long()
steps = torch.clamp((steps + 1) * 127.5, 0, 255).long()

# %%
#!g1.1
fig, axs = plt.subplots(2, 5, figsize=[13, 6])
fig.suptitle("Generated samples")
for i in range(len(samples)):
    axs[i % 2, i % 5].imshow(samples[i].permute(1, 2, 0).numpy())
plt.tight_layout()

# %%
#!g1.1
fig, axs = plt.subplots(1, len(steps), figsize=[13, 3])
fig.suptitle("Denoising process")
for i in range(len(steps)):
    axs[i].imshow(steps[i].permute(1, 2, 0).numpy(), cmap='gray')
plt.tight_layout()

# %%
#!g1.1
from torchmetrics.image.fid import FrechetInceptionDistance
from torchmetrics.image.inception import InceptionScore
from scipy.stats import norm
import torch

def compute_fid(real_data, generated_samples):
    fid = FrechetInceptionDistance(reset_real_features=False)
    fid.update(real_data, real=True)
    fid.update(generated_samples, real=False)
    return fid.compute().item()

def compute_is(generated_samples):
    inception = InceptionScore()
    # generate some images
    inception.update(generated_samples)
    return inception.compute().item()

def compute_nll(x, mean, std):
    upper_bound_cdf = norm.cdf(x + 1 / 255, loc=mean, scale=std)
    lower_bound_cdf = norm.cdf(x - 1 / 255, loc=mean, scale=std)
    # for x == -1
    log_upper_bound_cdf = torch.log(torch.from_numpy(upper_bound_cdf).clamp(min=1e-12))
    # for x == 1
    log_one_minus_lower_bound_cdf = torch.log(torch.from_numpy(1 - lower_bound_cdf).clamp(min=1e-12))
    # for -1 < x < 1
    log_delta_cdf = torch.log(torch.from_numpy(upper_bound_cdf - lower_bound_cdf).clamp(min=1e-12))
    log_likelihood = torch.where(
        torch.from_numpy(x) < -0.999, # == -1 
        log_upper_bound_cdf,
        torch.where(
            torch.from_numpy(x) > 0.999, # == 1
            log_one_minus_lower_bound_cdf,
            log_delta_cdf
        )
    )
    return -torch.mean(log_likelihood).item()

# %%
#!g1.1
from data.dataloader import get_dataloaders

train_loader, test_loader = get_dataloaders('CIFAR10')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
#!g1.1
# %pip install torchmetrics[image]
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 53 kB 1.3 MB/s
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.3.1 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.

# %%
#!g1.1
import torch_fidelity
import torch

# %%
#!g1.1
import os

os.environ['PATH'] += ':/home/jupyter/.local/bin'

# %%
#!g1.1
from model.ddpm import UNet

import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from torchvision.utils import make_grid


def sample_func(model, in_channels=3, n_samples=10, log_step=200, use_wandb=False, with_ema=False, SEED=42):
    # Fix seed to get the same pictures every time and see, how they are improving over time
    if SEED is not None:
        np.random.seed(SEED)
        torch.manual_seed(SEED)
        if torch.cuda.is_available():
            torch.cuda.manual_seed_all(SEED)
            torch.backends.cudnn.deterministic = True
    # Define device
    device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
    # Total number of diffusion process steps
    T = 1000
    # The authors suggest 2 ways of defining sigma_t, one of them is sigma_t^2 = beta_t.
    # Let's stick to this one
    beta_s = np.linspace(1e-4, 0.02, T)
    # Apla_t and ~alpha_t for denosing an image
    alpha_s = 1 - beta_s
    alpha_s_new = np.cumprod(alpha_s)
    # Model
    model = model.to(device)
    model.eval()
    # Let's get pure Gaussian noise to start with in the reverse diffusion process
    size = (n_samples, in_channels, 32, 32)
    x = torch.from_numpy(np.random.normal(loc=0.0, scale=1.0, size=size))
    # Save an example of how a particular image is being denoised to visualize later
    reverse_steps = [x[0].tolist()]
    # Finally, reverse diffusion process
    for t in range(T - 1, -1, -1):
        z = np.random.normal(loc=0.0, scale=1.0, size=size) if t > 0 else np.zeros(size)

        t_s = torch.tensor([t] * n_samples).to(device)
        x = x.to(device)
        with torch.no_grad():
            noise_predicted = model(x.float(), t_s)
        x = x.cpu()
        noise_predicted = noise_predicted.cpu()

        multiplier = (1 - alpha_s[t]) / ((1 - alpha_s_new[t]) ** (1/2))
        mean = (x - multiplier * noise_predicted) / (alpha_s[t] ** (1/2))
        x = (x - multiplier * noise_predicted) / (alpha_s[t] ** (1/2)) + (beta_s[t] ** (1/2)) * torch.from_numpy(z)

        if t % log_step == 0 or t == 0:
            reverse_steps.append(x[0].tolist())

    
    # Let's clip at the end - this is important, but we don't want to interfere with denosing process
    x = torch.clip(x, -1, 1)
    reverse_steps = torch.clip(torch.tensor(reverse_steps), -1, 1)

    x_to_log = torch.clamp((x + 1) * 127.5, 0, 255)
    x_to_log = x_to_log / 255
    reverse_steps_to_log = torch.clamp((reverse_steps + 1) * 127.5, 0, 255)
    reverse_steps_to_log = reverse_steps_to_log / 255
        
    if use_wandb:
        samples_title = 'samples (with EMA)' if with_ema else 'samples'
        reverse_step_title = 'reverse step (with EMA)' if with_ema else 'reverse step'
        wandb.log({samples_title: wandb.Image(make_grid(x_to_log, nrow=5))})
        wandb.log({reverse_step_title: wandb.Image(make_grid(reverse_steps_to_log, nrow=reverse_steps_to_log.shape[0]))})

    return x, reverse_steps

# %%
#!g1.1

# %%
#!g1.1
from torchvision.utils import save_image
from tqdm.auto import tqdm

#50_000
n_samples=500
n = 0
images = []
for i in tqdm(range(50_000 // n_samples)):
    samples, _ = sample_func(model, n_samples=n_samples, use_wandb=False, SEED=None)
    images.append((samples.cpu() + 1) / 2)
images = torch.cat(images, dim=0)#.numpy()
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "/kernel/lib/python3.8/site-packages/ml_kernel/state/state.py", line 99, in __eq__
#     self._unwrap()
#   File "/kernel/lib/python3.8/site-packages/ml_kernel/state/state.py", line 84, in _unwrap
#     raise Exception("variable not found")
# Exception: variable not found

# %%
#!g1.1
from torch.utils.data import Dataset

class Samples(Dataset):
    def __init__(self, images):
        self.data = (images * 255).type(torch.uint8)
        
    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx]

# %%
#!g1.1
samples = Samples(images)

metrics_dict = torch_fidelity.calculate_metrics(
    input1=samples, 
    input2='cifar10-train',
    batch_size=128,
    cuda=True, 
    isc=True, 
    fid=True, 
    kid=False, 
    verbose=True
)
# Out:
# Creating feature extractor "inception-v3-compat" with features ['logits_unbiased', '2048']
# Extracting features from input1
# Processing samples
# Extracting features from input2
# Loading cached /tmp/xdg_cache/torch/fidelity_cache/cifar10-train-inception-v3-compat-features-logits_unbiased.pt
# Loading cached /tmp/xdg_cache/torch/fidelity_cache/cifar10-train-inception-v3-compat-features-2048.pt
# Inception Score: 6.606844509721656 ± 0.10463727537838996
# Loading cached /tmp/xdg_cache/torch/fidelity_cache/cifar10-train-inception-v3-compat-stat-fid-2048.pt
# Frechet Inception Distance: 35.339251369706346

# %%
#!g1.1
metrics_dict
# Out:
# {'inception_score_mean': 6.606844509721656,
#  'inception_score_std': 0.10463727537838996,
#  'frechet_inception_distance': 35.339251369706346}

# %%
#!g1.1
metrics_dict = torch_fidelity.calculate_metrics(
    input1=samples, 
    input2='cifar10-train',
    batch_size=128,
    cuda=True, 
    isc=True, 
    fid=True, 
    kid=False, 
    verbose=True
)
# Out:
# Creating feature extractor "inception-v3-compat" with features ['logits_unbiased', '2048']
# Extracting features from input1
# Processing samples
# Extracting features from input2
# Loading cached /tmp/xdg_cache/torch/fidelity_cache/cifar10-train-inception-v3-compat-features-logits_unbiased.pt
# Loading cached /tmp/xdg_cache/torch/fidelity_cache/cifar10-train-inception-v3-compat-features-2048.pt
# Inception Score: 7.451526055050179 ± 0.09881920136289139
# Loading cached /tmp/xdg_cache/torch/fidelity_cache/cifar10-train-inception-v3-compat-stat-fid-2048.pt
# Frechet Inception Distance: 28.25088558092324

# %%
#!g1.1
metrics_dict
# Out:
# {'inception_score_mean': 7.451526066344465,
#  'inception_score_std': 0.09881921214416926,
#  'frechet_inception_distance': 28.25088558092324}

# %%
#!g1.1
from scipy.stats import norm
import torch

# "3.3 Data scaling, reverse process decoder, and L0" in the paper
# + https://github.com/openai/guided-diffusion/blob/22e0df8183507e13a7813f8d38d51b072ca1e67c/guided_diffusion/losses.py#L50  
def compute_nll(x, mean, std):
    upper_bound_cdf = norm.cdf(x + 1 / 255, loc=mean, scale=std)
    lower_bound_cdf = norm.cdf(x - 1 / 255, loc=mean, scale=std)
    # for x == -1
    log_upper_bound_cdf = torch.log(torch.from_numpy(upper_bound_cdf).clamp(min=1e-12))
    # for x == 1
    log_one_minus_lower_bound_cdf = torch.log(torch.from_numpy(1 - lower_bound_cdf).clamp(min=1e-12))
    # for -1 < x < 1
    log_delta_cdf = torch.log(torch.from_numpy(upper_bound_cdf - lower_bound_cdf).clamp(min=1e-12))
    log_likelihood = torch.where(
        torch.from_numpy(x) < -0.999, # == -1 
        log_upper_bound_cdf,
        torch.where(
            torch.from_numpy(x) > 0.999, # == 1
            log_one_minus_lower_bound_cdf,
            log_delta_cdf
        )
    )
    return log_likelihood

# %%
#!g1.1
from data.dataloader import get_dataloaders

train_loader, test_loader = get_dataloaders('CIFAR10')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
#!g1.1
import torch
import numpy as np
from tqdm.auto import tqdm

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

T = 1000
beta_s = np.linspace(1e-4, 0.02, T)
# Apla_t and ~alpha_t for denosing an image
alpha_s = 1 - beta_s
alpha_s_new = np.cumprod(alpha_s)

nll = 0.
t = 1
for batch, _ in tqdm(train_loader):
    n_samples = batch.shape[0]
    t_s = torch.tensor([1]).expand(n_samples).numpy()
    # Noise the images
    noise_s = np.random.normal(loc=0.0, scale=1.0, size=batch.shape)
    alpha_s_cur = alpha_s_new[t_s]
    noised_inputs = np.expand_dims(alpha_s_cur ** (1/2), axis=(1, 2, 3)) * batch.numpy() + np.expand_dims((1 - alpha_s_cur) ** (1/2), axis=(1, 2, 3)) * noise_s

    t_s = torch.from_numpy(t_s).to(device)
    noised_inputs = torch.from_numpy(noised_inputs).float().to(device)
    targets = torch.from_numpy(noise_s).float().to(device)

    with torch.no_grad():
        outputs = ema(noised_inputs, t_s)
    outputs = outputs.cpu()
    noised_inputs = noised_inputs.cpu()
    # get mean and std
    multiplier = (1 - alpha_s[t]) / ((1 - alpha_s_new[t]) ** (1/2))
    mean = (noised_inputs - multiplier * outputs) / (alpha_s[t] ** (1/2))
    
    nll += compute_nll(batch.cpu().numpy(), mean.cpu().numpy(), beta_s[t] ** (1/2))
# Out:
#   0%|          | 0/391 [00:00<?, ?it/s]

# %%
#!g1.1
def kl_between_normal(mu_0, var_0, mu_1, var_1):  # element-wise
    tensor = None
    for obj in (mu_0, var_0, mu_1, var_1):
        if isinstance(obj, torch.Tensor):
            tensor = obj
            break
    assert tensor is not None

    var_0, var_1 = [
        x if isinstance(x, torch.Tensor) else torch.tensor(x).to(tensor)
        for x in (var_0, var_1)
    ]

    return 0.5 * (var_0 / var_1 + (mu_0 - mu_1).pow(2) / var_1 + var_1.log() - var_0.log() - 1.)

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

T = 1000
beta_s = np.linspace(1e-4, 0.02, T)
# Apla_t and ~alpha_t for denosing an image
alpha_s = 1 - beta_s
alpha_s_new = np.cumprod(alpha_s)

nll = 0.

for batch, _ in tqdm(train_loader):
    nelbo = torch.zeros(batch.size(0))

    for t in tqdm(range(T - 1, -1, -1), desc='Sampling'):
        n_samples = batch.shape[0]
        t_s = torch.tensor([t]).expand(n_samples).numpy()
        noise_s = np.random.normal(loc=0.0, scale=1.0, size=batch.shape)
        alpha_s_cur = alpha_s_new[t_s]
        noised_inputs = np.expand_dims(alpha_s_cur ** (1/2), axis=(1, 2, 3)) * batch.numpy() + np.expand_dims((1 - alpha_s_cur) ** (1/2), axis=(1, 2, 3)) * noise_s
        
        with torch.no_grad():
            t_s = torch.from_numpy(t_s).to(device)
            noised_inputs = torch.from_numpy(noised_inputs).float().to(device)
            targets = torch.from_numpy(noise_s).float().to(device)
            outputs = model(noised_inputs, t_s)
        
        batch = batch.cpu()
        outputs = outputs.cpu()
        noised_inputs = noised_inputs.cpu()
        
        multiplier = (1 - alpha_s[t]) / ((1 - alpha_s_new[t]) ** (1/2))
        mu_p = (noised_inputs - multiplier * outputs) / (alpha_s[t] ** (1/2))
        
        #z = np.random.normal(loc=0.0, scale=1.0, size=batch.size) if t > 0 else np.ones(batch.size)
        var_p = (beta_s[t] ** (1/2)) * torch.ones(batch.size())
        

        if t != 0:
            mu_q = alpha_s_new[t - 1] ** (1/2) * beta_s[t] / (1 - alpha_s_new[t]) * batch + \
                alpha_s_new[t] ** (1/2) * (1 - alpha_s_new[t - 1]) / (1 - alpha_s_new[t]) * noised_inputs
            
            var_q = (1 - alpha_s_new[t - 1]) * beta_s[t] / (1 - alpha_s_new[t]) * torch.ones(batch.size())
            
            term = kl_between_normal(mu_q, var_q, mu_p, var_p).flatten(1).sum(1)
        else:
            term = -compute_nll(batch.numpy(), mu_p.numpy(), var_p.numpy()).flatten(1).sum(1)
        nelbo += term

    nll += nelbo.sum().item()
# Out:
# ...
# Sampling:   0%|          | 0/1000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-1cb30c67ecd8> in <module>
#      41
#      42         batch = batch.cpu()
# ---> 43         outputs = outputs.cpu()
#      44         noised_inputs = noised_inputs.cpu()
#      45
#
# KeyboardInterrupt:

# %%
#!g1.1
nll /= len(train_loader.dataset)

# %%
#!g1.1
print('NLL Train: {}'.format(nll))

# %%
#!g1.1
nll_tets = 0.
t = 1
for batch, _ in tqdm(test_loader):
    n_samples = batch.shape[0]
    t_s = torch.tensor([1]).expand(n_samples).numpy()
    # Noise the images
    noise_s = np.random.normal(loc=0.0, scale=1.0, size=batch.shape)
    alpha_s_cur = alpha_s_new[t_s]
    noised_inputs = np.expand_dims(alpha_s_cur ** (1/2), axis=(1, 2, 3)) * batch.numpy() + np.expand_dims((1 - alpha_s_cur) ** (1/2), axis=(1, 2, 3)) * noise_s

    t_s = torch.from_numpy(t_s).to(device)
    noised_inputs = torch.from_numpy(noised_inputs).float().to(device)
    targets = torch.from_numpy(noise_s).float().to(device)

    with torch.no_grad():
        outputs = ema(noised_inputs, t_s)
    outputs = outputs.cpu()
    noised_inputs = noised_inputs.cpu()
    # get mean and std
    multiplier = (1 - alpha_s[t]) / ((1 - alpha_s_new[t]) ** (1/2))
    mean = (noised_inputs - multiplier * outputs) / (alpha_s[t] ** (1/2))
    
    nll_test += compute_nll(batch.cpu().numpy(), mean.cpu().numpy(), beta_s[t] ** (1/2))

# %%
#!g1.1

# %%
#!g1.1
from torchvision.utils import save_image
from tqdm.auto import tqdm

#50_000
n_samples=500
n = 0
for i in tqdm(range(50_000 // n_samples)):
    samples, _ = sample_func(ema, n_samples=n_samples, use_wandb=False, SEED=None)
    for sample in samples:
        sample = torch.clamp((sample + 1) * 127.5, 0, 255) / 255
        save_image(sample, fp='samples_png/{}.png'.format(n))
        n+=1
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
#!g1.1
metrics_dict = torch_fidelity.calculate_metrics(
    input1='./samples_png', 
    input2='cifar10-train',
    batch_size=128,
    cuda=True, 
    isc=True, 
    fid=True, 
    kid=False, 
    verbose=True
)
# Out:
# Creating feature extractor "inception-v3-compat" with features ['logits_unbiased', '2048']
# Extracting features from input1
# Looking for samples non-recursivelty in "./samples_png" with extensions png,jpg,jpeg
# Found 50000 samples
# Processing samples
# Extracting features from input2
# Loading cached /tmp/xdg_cache/torch/fidelity_cache/cifar10-train-inception-v3-compat-features-logits_unbiased.pt
# Loading cached /tmp/xdg_cache/torch/fidelity_cache/cifar10-train-inception-v3-compat-features-2048.pt
# Inception Score: 7.449742561053085 ± 0.05929653554900749
# Loading cached /tmp/xdg_cache/torch/fidelity_cache/cifar10-train-inception-v3-compat-stat-fid-2048.pt
# Frechet Inception Distance: 28.25887946346768

# %%
#!g1.1
metrics_dict
# Out:
# {'inception_score_mean': 7.449742561053085,
#  'inception_score_std': 0.05929653554900749,
#  'frechet_inception_distance': 28.25887946346768}

# %%
#!g1.1

# %%
#!g1.1
metrics_dict = torch_fidelity.calculate_metrics(
    input1='./samples', 
    input2='cifar10-train',
    batch_size=128,
    cuda=True, 
    isc=True, 
    fid=True, 
    kid=False, 
    verbose=True
)
# Out:
#   0%|          | 0.00/91.2M [00:00<?, ?B/s]
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Creating feature extractor "inception-v3-compat" with features ['logits_unbiased', '2048']
# Downloading: "https://github.com/toshas/torch-fidelity/releases/download/v0.2.0/weights-inception-2015-12-05-6726825d.pth" to /tmp/xdg_cache/torch/hub/checkpoints/weights-inception-2015-12-05-6726825d.pth
# Extracting features from input1
# Looking for samples non-recursivelty in "./samples" with extensions png,jpg,jpeg
# Found 50000 samples, some are lossy-compressed - this may affect metrics
# Processing samples
# Extracting features from input2
# ...
# Extracting /tmp/xdg_cache/torch/fidelity_datasets/cifar-10-python.tar.gz to /tmp/xdg_cache/torch/fidelity_datasets
# Processing samples
# Caching /tmp/xdg_cache/torch/fidelity_cache/cifar10-train-inception-v3-compat-features-logits_unbiased.pt
# Caching /tmp/xdg_cache/torch/fidelity_cache/cifar10-train-inception-v3-compat-features-2048.pt
# ...

# %%
#!g1.1
metrics_dict
# Out:
# {'inception_score_mean': 6.378915393451367,
#  'inception_score_std': 0.04992981992505731,
#  'frechet_inception_distance': 51.116973427600215}

# %%
#!g1.1
import wandb


wandb.init(project='ddpm_cifar10', resume='must', id='el2qzh0l')

wandb.log(
    {
        'metrics': wandb.Table(
            columns=["FID", "IS"], 
            data=[
                str(metrics_dict['frechet_inception_distance']),
                '{}±{}'.format(metrics_dict['inception_score_mean'], metrics_dict['inception_score_std'])
            ]
        )
    }
)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: huwarr. Use `wandb login --relogin` to force relogin
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/home/jupyter/work/resources/ddpm/wandb/run-20221207_191508-el2qzh0l</code>
# Resuming run <strong><a href="https://wandb.ai/huwarr/ddpm_cifar10/runs/el2qzh0l" target="_blank">sunny-capybara-2</a></strong> to <a href="https://wandb.ai/huwarr/ddpm_cifar10" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-05061928aa9c> in <module>
#       6 wandb.log(
#       7     {
# ...

# %%
#!g1.1
fid = FrechetInceptionDistance(reset_real_features=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-fa58aa262fe6> in <module>
# ----> 1 fid = FrechetInceptionDistance(reset_real_features=False)
#       2 #
#
# ~/.local/lib/python3.8/site-packages/torchmetrics/image/fid.py in __init__(self, feature, reset_real_features, normalize, **kwargs)
#     223             num_features = feature
#     224             if not _TORCH_FIDELITY_AVAILABLE:
# --> 225                 raise ModuleNotFoundError(
#     226                     "FrechetInceptionDistance metric requires that `Torch-fidelity` is installed."
#     227                     " Either install as `pip install torchmetrics[image]` or `pip install torch-fidelity`."
#
# ModuleNotFoundError: FrechetInceptionDistance metric requires that `Torch-fidelity` is installed. Either install as `pip install torchmetrics[image]` or `pip install torch-fidelity`.

# %%
#!g1.1
for batch, _ in tqdm(train_loader):
    batch = torch.clamp((batch + 1) * 127.5, 0, 255).long()
    fid.update(batch, real=True)

# %%
#!g1.1
fid = FrechetInceptionDistance(reset_real_features=False)
fid.update(real_data, real=True)
fid.update(generated_samples, real=False)

# %%
#!g1.1

# %%
#!g1.1
